# %% [markdown]
# EVERCISE SET 2
# Data analysis with pandas

# %% [markdown]
# SERIES
#
#
# 1.	Write a Pandas program to compare the elements of two Pandas series.

# %%
import pandas as pd
l1 = pd.Series([4,65,436,3,9])
l2 = pd.Series([7,0,3,897,9])

print (l1 == l2)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %% [markdown]
# 2.	Write a Pandas program to add, subtract, multiply and divide two Pandas series.

# %%
s1 = pd.Series([2,4,6,8,14])
s2 = pd.Series([1,3,5,7,9])

sum = s1 + s2
product = s1 * s2
diff = s2 - s1
div = s2/s1

print (sum)
print(product)
print(diff)
print(div)
# Out:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
# 0   -1
# 1   -1
# 2   -1
# 3   -1
# 4   -5
# dtype: int64
# 0    0.500000
# 1    0.750000
# 2    0.833333
# 3    0.875000
# 4    0.642857
# dtype: float64

# %% [markdown]
# 3.	Write a Pandas program to convert a dictionary to a Pandas series.

# %%
dictionary1 ={'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}

dict = pd.Series(dictionary1)
print(dict)
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %% [markdown]
# 4.	Write a Pandas program to convert a given series to an array.

# %%
ser = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])

arr = ser.values
print(arr)
# Out:
# ['Love' 800 'Joy' 789.9 'Peace' True]

# %% [markdown]
# 5.	Write a Pandas program to display the most frequent value in the given series and replace everything else as ‘Other’ in the series.

# %%
df = pd.read_csv('AfricaCupofNationsMatches.csv')
freq = df.value_counts().idxmax()
mapping = {value: value if value == freq else 'Other' for value in df}
df = df.replace(mapping)
print(df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0            0.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 617            0.0            3.0        Quarter-finals
# 618            1.0            0.0           Semi-finals
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 617                                                NaN
# 618                              win after extra time
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
#
#                          Stadium       City  Attendance
# 0              Municipal Stadium   Khartoum     30000.0
# 1                            NaN        NaN         NaN
# 2              Municipal Stadium   Khartoum     30000.0
# 3          Prince Farouk Stadium      Cairo     30000.0
# 4          Prince Farouk Stadium      Cairo     20000.0
# ..                           ...        ...         ...
# 617             Al Salam Stadium      Cairo      7568.0
# 618              30 June Stadium      Cairo      9143.0
# 619  Cairo International Stadium      Cairo     49775.0
# 620             Al Salam Stadium      Cairo      6340.0
# 621  Cairo International Stadium      Cairo     75000.0
#
# [622 rows x 12 columns]

# %% [markdown]
# DATA FRAMES
#
#
# 1.	Write a Pandas program to read the given csv file.

# %%
df = pd.read_csv('AfricaCupofNationsMatches.csv')

# %% [markdown]
# 2.	Write a Pandas program to get the first 7 rows of your data frame.

# %%
rows = df.head(7).to_string()
print(rows)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals             Stage                                  SpecialWinConditions                 Stadium          City  Attendance
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0            2.0        Semifinals                                                   NaN       Municipal Stadium      Khartoum     30000.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN            NaN        Semifinals  Ethiopia  wins due to disqualification of other team                     NaN           NaN         NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0            0.0             Final                                                   NaN       Municipal Stadium      Khartoum     30000.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0            0.0  Final Tournament                                                   NaN   Prince Farouk Stadium         Cairo     30000.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0            0.0  Final Tournament                                                   NaN   Prince Farouk Stadium         Cairo     20000.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0            1.0  Final Tournament                                                   NaN   Prince Farouk Stadium         Cairo     30000.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0            2.0        Semifinals                                                   NaN  Hailé Sélassié Stadium   Addis Ababa     30000.0

# %%
selected_columns =['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']
df1 = df[selected_columns]
print(df1)
# Out:
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %% [markdown]
# 4.	Write a Pandas program to select the rows where Egypt appears.

# %%
df2 = df[(df['HomeTeam'] == 'Egypt') | (df['AwayTeam'] == 'Egypt')]
print(df2)
# Out:
#     Year      Date  Time    HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959  22-May-59   NaN      Egypt   Ethiopia            4.0            0.0
# 5   1959  29-May-59   NaN      Egypt      Sudan            2.0            1.0
# 7   1962  18-Jan-62   NaN      Egypt     Uganda            2.0            1.0
# 9   1962  21-Jan-62   NaN  Ethiopia       Egypt            4.0            2.0
# 13  1963  24-Nov-63   NaN      Egypt    Nigeria            6.0            3.0
# 14  1963  26-Nov-63   NaN      Egypt      Sudan            2.0            2.0
# 16  1963  30-Nov-63   NaN      Egypt   Ethiopia            3.0            0.0
#
#                 Stage    SpecialWinConditions                 Stadium  \
# 3    Final Tournament                     NaN   Prince Farouk Stadium
# 5    Final Tournament                     NaN   Prince Farouk Stadium
# 7          Semifinals                     NaN  Hailé Sélassié Stadium
# 9               Final   win after extra time   Hailé Sélassié Stadium
# 13            Group B                     NaN   Kumasi Sports Stadium
# 14            Group B                     NaN   Kumasi Sports Stadium
# 16  Third place match                     NaN    Accra Sports Stadium
#
#             City  Attendance
# 3          Cairo     30000.0
# 5          Cairo     30000.0
# 7    Addis Ababa     30000.0
# 9    Addis Ababa         NaN
# 13        Kumasi         NaN
# 14        Kumasi         NaN
# 16         Accra         NaN

# %% [markdown]
# 5.	Write a Pandas program to count the number of rows and columns of your data frame.

# %%
num_rows = df.shape[0]
num_columns = df.shape[1]

print('Rows:', num_rows)
print('colums:', num_columns)
# Out:
# Rows: 622
# colums: 12

# %% [markdown]
# 6.	Write a Pandas program to select the rows where the ‘Attendance’ is missing.

# %%
df6 = df[df['Attendance'].isnull()]
print(df6)
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 1              NaN            NaN            Semifinals
# 8              3.0            0.0     Third place match
# 9              4.0            2.0                 Final
# 10             1.0            1.0               Group A
# 11             2.0            0.0               Group A
# ..             ...            ...                   ...
# 565            1.0            0.0        Quarter-finals
# 566            1.0            1.0           Semi-finals
# 567            2.0            0.0           Semi-finals
# 568            1.0            0.0  Third place play-off
# 569            1.0            2.0                 Final
#
#                                   SpecialWinConditions  \
# 1    Ethiopia  wins due to disqualification of othe...
# 8                                                  NaN
# 9                                win after extra time
# 10                                                 NaN
# 11                                                 NaN
# ..                                                 ...
# 565                                                NaN
# 566                        Egypt win on Penalities 3-4
# 567                                                NaN
# 568                                                NaN
# 569                                                NaN
#
#                     Stadium          City  Attendance
# 1                       NaN           NaN         NaN
# 8    Hailé Sélassié Stadium   Addis Ababa         NaN
# 9    Hailé Sélassié Stadium   Addis Ababa         NaN
# 10     Accra Sports Stadium         Accra         NaN
# 11     Accra Sports Stadium         Accra         NaN
# ..                      ...           ...         ...
# 565    Stade de Port-Gentil   Port-Gentil         NaN
# 566       Stade de l'Amitié    Libreville         NaN
# 567    Stade de Franceville   Franceville         NaN
# 568    Stade de Port-Gentil   Port-Gentil         NaN
# 569       Stade de l'Amitié    Libreville         NaN
#
# [100 rows x 12 columns]

# %% [markdown]
# 7.	Write a Pandas program to select the rows where the ‘HomeTeamGoals’ are between 3 and 6 inclusive.

# %%
goals = pd.Series([3,4,5,6])
df3 = df[(df['HomeTeamGoals'] >=3) & (df['HomeTeamGoals']<=6) ]
print(df3)
# Out:
#      Year                         Date   Time    HomeTeam     AwayTeam  \
# 2    1957                     16-Feb-57    NaN     Egypt      Ethiopia
# 3    1959                     22-May-59    NaN      Egypt     Ethiopia
# 6    1962                     14-Jan-62    NaN  Ethiopia       Tunisia
# 8    1962                     20-Jan-62    NaN   Tunisia        Uganda
# 9    1962                     21-Jan-62    NaN  Ethiopia         Egypt
# ..    ...                           ...    ...        ...          ...
# 553  2017  20 January 2017 (2017-01-20)  20:00   Morocco          Togo
# 585  2019     27 June 2019 (2019-06-27)  22:00     Kenya      Tanzania
# 595  2019     24 June 2019 (2019-06-24)  22:00      Mali    Mauritania
# 608  2019      6 July 2019 (2019-07-06)  18:00   Nigeria      Cameroon
# 611  2019      7 July 2019 (2019-07-07)  21:00   Algeria        Guinea
#
#      HomeTeamGoals  AwayTeamGoals              Stage    SpecialWinConditions  \
# 2              4.0            0.0              Final                     NaN
# 3              4.0            0.0   Final Tournament                     NaN
# 6              4.0            2.0         Semifinals                     NaN
# 8              3.0            0.0  Third place match                     NaN
# 9              4.0            2.0              Final   win after extra time
# ..             ...            ...                ...                     ...
# 553            3.0            1.0            Group C                     NaN
# 585            3.0            2.0            Group C                     NaN
# 595            4.0            1.0            Group E                     NaN
# 608            3.0            2.0        Round of 16                     NaN
# 611            3.0            0.0        Round of 16                     NaN
#
#                     Stadium          City  Attendance
# 2         Municipal Stadium      Khartoum     30000.0
# 3     Prince Farouk Stadium         Cairo     30000.0
# 6    Hailé Sélassié Stadium   Addis Ababa     30000.0
# 8    Hailé Sélassié Stadium   Addis Ababa         NaN
# 9    Hailé Sélassié Stadium   Addis Ababa         NaN
# ..                      ...           ...         ...
# 553            Stade d'Oyem          Oyem         NaN
# 585         30 June Stadium         Cairo      7233.0
# 595            Suez Stadium          Suez      6202.0
# 608      Alexandria Stadium    Alexandria     10000.0
# 611         30 June Stadium         Cairo      8205.0
#
# [138 rows x 12 columns]

# %% [markdown]
# 8.	Write a Pandas program to change the “AwayTeamGoals” in the 3rd row to 10.

# %%
df.at[2, 'AwayTeamGoals'] = 10
print (df)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0           10.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 617            0.0            3.0        Quarter-finals
# 618            1.0            0.0           Semi-finals
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 617                                                NaN
# 618                              win after extra time
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
#
#                          Stadium       City  Attendance
# 0              Municipal Stadium   Khartoum     30000.0
# 1                            NaN        NaN         NaN
# 2              Municipal Stadium   Khartoum     30000.0
# 3          Prince Farouk Stadium      Cairo     30000.0
# 4          Prince Farouk Stadium      Cairo     20000.0
# ..                           ...        ...         ...
# 617             Al Salam Stadium      Cairo      7568.0
# 618              30 June Stadium      Cairo      9143.0
# 619  Cairo International Stadium      Cairo     49775.0
# 620             Al Salam Stadium      Cairo      6340.0
# 621  Cairo International Stadium      Cairo     75000.0
#
# [622 rows x 12 columns]

# %% [markdown]
# 9.	Write a Pandas program to sort the DataFrame first by ‘HomeTeam’ in ascending order, then by ‘HomeTeamScores’ in descending order.

# %%
df5 = df.sort_values(by=['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])
print (df5)
# Out:
#      Year                         Date           Time    HomeTeam  \
# 205  1990                      2-Mar-90            NaN   Algeria
# 29   1968                     14-Jan-68            NaN   Algeria
# 135  1980                     16-Mar-80            NaN   Algeria
# 164  1984                      5-Mar-84            NaN   Algeria
# 171  1984                     17-Mar-84            NaN   Algeria
# ..    ...                           ...            ...        ...
# 521  2012                     12-Feb-12  20:30[note 1]    Zambia
# 549  2017  23 January 2017 (2017-01-23)          20:00  Zimbabwe
# 398  2004                     25-Jan-04          16:30  Zimbabwe
# 437  2006                     23-Jan-06          20:00  Zimbabwe
# 575  2019     30 June 2019 (2019-06-30)          21:00  Zimbabwe
#
#          AwayTeam  HomeTeamGoals  AwayTeamGoals              Stage  \
# 205       Nigeria            5.0            1.0            Group A
# 29         Uganda            4.0            0.0            Group A
# 135        Guinea            3.0            2.0            Group B
# 164        Malawi            3.0            0.0            Group B
# 171         Egypt            3.0            1.0  Third place match
# ..            ...            ...            ...                ...
# 521   Ivory Coast            0.0            0.0              Final
# 549       Tunisia            2.0            4.0            Group B
# 398         Egypt            1.0            2.0            Group C
# 437       Senegal            0.0            2.0            Group D
# 575      DR Congo            0.0            4.0            Group A
#
#               SpecialWinConditions                       Stadium  \
# 205                            NaN          Stade 5 Juillet 1962
# 29                             NaN        Hailé Sélassié Stadium
# 135                            NaN               Liberty Stadium
# 164                            NaN                  Stade Bouaké
# 171                            NaN  Stade Félix Houphouët-Boigny
# ..                             ...                           ...
# 521  Zambia  win on Penalities 8-7              Stade d'Angondjé
# 549                            NaN             Stade de l'Amitié
# 398                            NaN          Stade Taïeb El Mhiri
# 437                            NaN             Port Said Stadium
# 575                            NaN               30 June Stadium
#
#              City  Attendance
# 205       Algiers     85000.0
# 29    Addis Ababa     25000.0
# 135        Ibadan     20000.0
# 164        Bouaké     10000.0
# 171       Abidjan       500.0
# ..            ...         ...
# 521    Libreville     40000.0
# 549    Libreville         NaN
# 398          Sfax     22000.0
# 437     Port Said     15000.0
# 575         Cairo      4364.0
#
# [622 rows x 12 columns]

# %% [markdown]
# 10.	Write a Pandas program to get list from DataFrame column headers.

# %%
column = df.columns.tolist()
print(column)
# Out:
# ['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City', 'Attendance']

# %% [markdown]
# 11.	Write a Pandas program to append a column of your choice to your DataFrame.

# %%
cols = df.columns
df['Form'] = cols.append
print(df.columns)
# Out:
# Index(['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
#        'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City',
#        'Attendance', 'Form'],
#       dtype='object')

# %% [markdown]
# 12.	Write a Pandas program to add 2 rows to your DataFrame.

# %%
new_row1 = {}  
new_row2 = {}  

df.loc[len(df)] = new_row1
df.loc[len(df)] = new_row2

print(df)
# Out:
#        Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957.0                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957.0                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959.0                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959.0                  25-May-59    NaN     Sudan        Ethiopia
# ..      ...                        ...    ...        ...            ...
# 619  2019.0  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019.0  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019.0  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622     NaN                        NaN    NaN        NaN            NaN
# 623     NaN                        NaN    NaN        NaN            NaN
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0           10.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
# 622            NaN            NaN                   NaN
# 623            NaN            NaN                   NaN
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
#
#                          Stadium       City  Attendance  \
# 0              Municipal Stadium   Khartoum     30000.0
# 1                            NaN        NaN         NaN
# 2              Municipal Stadium   Khartoum     30000.0
# 3          Prince Farouk Stadium      Cairo     30000.0
# 4          Prince Farouk Stadium      Cairo     20000.0
# ..                           ...        ...         ...
# 619  Cairo International Stadium      Cairo     49775.0
# 620             Al Salam Stadium      Cairo      6340.0
# 621  Cairo International Stadium      Cairo     75000.0
# 622                          NaN        NaN         NaN
# 623                          NaN        NaN         NaN
#
#                                                   Form
# 0    <bound method Index.append of Index(['Year', '...
# 1    <bound method Index.append of Index(['Year', '...
# 2    <bound method Index.append of Index(['Year', '...
# 3    <bound method Index.append of Index(['Year', '...
# 4    <bound method Index.append of Index(['Year', '...
# ..                                                 ...
# 619  <bound method Index.append of Index(['Year', '...
# 620  <bound method Index.append of Index(['Year', '...
# 621  <bound method Index.append of Index(['Year', '...
# 622                                                NaN
# 623                                                NaN
#
# [624 rows x 13 columns]

# %% [markdown]
# 13.	Write a Pandas program to change the country ‘Uganda’ to ‘China’ in the ‘AwayTeam’ column of the DataFrame.

# %%
val = df[df['AwayTeam'] == 'Uganda']
mapp = {value: 'China' if value == 'Uganda' else value for value in df }
df = df.replace(mapp)
print(df)
# Out:
#        Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957.0                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957.0                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959.0                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959.0                  25-May-59    NaN     Sudan        Ethiopia
# ..      ...                        ...    ...        ...            ...
# 619  2019.0  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019.0  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019.0  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622     NaN                        NaN    NaN        NaN            NaN
# 623     NaN                        NaN    NaN        NaN            NaN
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0           10.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
# 622            NaN            NaN                   NaN
# 623            NaN            NaN                   NaN
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
#
#                          Stadium       City  Attendance  \
# 0              Municipal Stadium   Khartoum     30000.0
# 1                            NaN        NaN         NaN
# 2              Municipal Stadium   Khartoum     30000.0
# 3          Prince Farouk Stadium      Cairo     30000.0
# 4          Prince Farouk Stadium      Cairo     20000.0
# ..                           ...        ...         ...
# 619  Cairo International Stadium      Cairo     49775.0
# 620             Al Salam Stadium      Cairo      6340.0
# 621  Cairo International Stadium      Cairo     75000.0
# 622                          NaN        NaN         NaN
# 623                          NaN        NaN         NaN
#
#                                                   Form
# 0    <bound method Index.append of Index(['Year', '...
# 1    <bound method Index.append of Index(['Year', '...
# 2    <bound method Index.append of Index(['Year', '...
# 3    <bound method Index.append of Index(['Year', '...
# 4    <bound method Index.append of Index(['Year', '...
# ..                                                 ...
# 619  <bound method Index.append of Index(['Year', '...
# 620  <bound method Index.append of Index(['Year', '...
# 621  <bound method Index.append of Index(['Year', '...
# 622                                                NaN
# 623                                                NaN
#
# [624 rows x 13 columns]

# %% [markdown]
# 14.	Write a Pandas program to reset index in your DataFrame.

# %%
df8=df.reset_index(drop=True)
print(df8)
# Out:
#        Year                      Date   Time    HomeTeam       AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN     Sudan           Egypt
# 1    1957.0                  10-Feb-57    NaN  Ethiopia    South Africa
# 2    1957.0                  16-Feb-57    NaN     Egypt        Ethiopia
# 3    1959.0                  22-May-59    NaN      Egypt       Ethiopia
# 4    1959.0                  25-May-59    NaN     Sudan        Ethiopia
# ..      ...                        ...    ...        ...            ...
# 619  2019.0  14 July 2019 (2019-07-14)  21:00   Algeria         Nigeria
# 620  2019.0  17 July 2019 (2019-07-17)  21:00   Tunisia         Nigeria
# 621  2019.0  19 July 2019 (2019-07-19)  21:00   Senegal         Algeria
# 622     NaN                        NaN    NaN        NaN            NaN
# 623     NaN                        NaN    NaN        NaN            NaN
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# 0              1.0            2.0            Semifinals
# 1              NaN            NaN            Semifinals
# 2              4.0           10.0                 Final
# 3              4.0            0.0      Final Tournament
# 4              1.0            0.0      Final Tournament
# ..             ...            ...                   ...
# 619            2.0            1.0           Semi-finals
# 620            0.0            1.0  Third place play-off
# 621            0.0            1.0                 Final
# 622            NaN            NaN                   NaN
# 623            NaN            NaN                   NaN
#
#                                   SpecialWinConditions  \
# 0                                                  NaN
# 1    Ethiopia  wins due to disqualification of othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
# 622                                                NaN
# 623                                                NaN
#
#                          Stadium       City  Attendance  \
# 0              Municipal Stadium   Khartoum     30000.0
# 1                            NaN        NaN         NaN
# 2              Municipal Stadium   Khartoum     30000.0
# 3          Prince Farouk Stadium      Cairo     30000.0
# 4          Prince Farouk Stadium      Cairo     20000.0
# ..                           ...        ...         ...
# 619  Cairo International Stadium      Cairo     49775.0
# 620             Al Salam Stadium      Cairo      6340.0
# 621  Cairo International Stadium      Cairo     75000.0
# 622                          NaN        NaN         NaN
# 623                          NaN        NaN         NaN
#
#                                                   Form
# 0    <bound method Index.append of Index(['Year', '...
# 1    <bound method Index.append of Index(['Year', '...
# 2    <bound method Index.append of Index(['Year', '...
# 3    <bound method Index.append of Index(['Year', '...
# 4    <bound method Index.append of Index(['Year', '...
# ..                                                 ...
# 619  <bound method Index.append of Index(['Year', '...
# 620  <bound method Index.append of Index(['Year', '...
# 621  <bound method Index.append of Index(['Year', '...
# 622                                                NaN
# 623                                                NaN
#
# [624 rows x 13 columns]

# %% [markdown]
# 15.	Write a Pandas program to check whether the ‘Stadium’ column is present in your DataFrame or not.

# %%
if 'Stadiun' in df.columns:
    print('Column present')
else:
    print('Column absent')
# Out:
# Column absent

# %% [markdown]
# 16.	Write a Pandas program to convert the datatype of the ‘AwayTeamGoals’. (int to float)

# %%
df['AwayTeamGoals'] = df['AwayTeamGoals'].astype(float)

# %% [markdown]
# 17.	Write a Pandas program to remove the last 10 rows from your DataFrame.

# %%
df9 = df.iloc[:-10]
print(df9)
# Out:
#        Year                      Date   Time        HomeTeam       AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN         Sudan           Egypt
# 1    1957.0                  10-Feb-57    NaN      Ethiopia    South Africa
# 2    1957.0                  16-Feb-57    NaN         Egypt        Ethiopia
# 3    1959.0                  22-May-59    NaN          Egypt       Ethiopia
# 4    1959.0                  25-May-59    NaN         Sudan        Ethiopia
# ..      ...                        ...    ...            ...            ...
# 589  2019.0  24 June 2019 (2019-06-24)  16:30   Ivory Coast    South Africa
# 590  2019.0  28 June 2019 (2019-06-28)  19:00       Morocco     Ivory Coast
# 591  2019.0  28 June 2019 (2019-06-28)  22:00  South Africa         Namibia
# 592  2019.0   1 July 2019 (2019-07-01)  18:00  South Africa         Morocco
# 593  2019.0   1 July 2019 (2019-07-01)  18:00       Namibia     Ivory Coast
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# 1              NaN            NaN        Semifinals
# 2              4.0           10.0             Final
# 3              4.0            0.0  Final Tournament
# 4              1.0            0.0  Final Tournament
# ..             ...            ...               ...
# 589            1.0            0.0           Group D
# 590            1.0            0.0           Group D
# 591            1.0            0.0           Group D
# 592            0.0            1.0           Group D
# 593            1.0            4.0           Group D
#
#                                   SpecialWinConditions                Stadium  \
# 0                                                  NaN      Municipal Stadium
# 1    Ethiopia  wins due to disqualification of othe...                    NaN
# 2                                                  NaN      Municipal Stadium
# 3                                                  NaN  Prince Farouk Stadium
# 4                                                  NaN  Prince Farouk Stadium
# ..                                                 ...                    ...
# 589                                                NaN       Al Salam Stadium
# 590                                                NaN       Al Salam Stadium
# 591                                                NaN       Al Salam Stadium
# 592                                                NaN       Al Salam Stadium
# 593                                                NaN        30 June Stadium
#
#           City  Attendance                                               Form
# 0     Khartoum     30000.0  <bound method Index.append of Index(['Year', '...
# 1          NaN         NaN  <bound method Index.append of Index(['Year', '...
# 2     Khartoum     30000.0  <bound method Index.append of Index(['Year', '...
# 3        Cairo     30000.0  <bound method Index.append of Index(['Year', '...
# 4        Cairo     20000.0  <bound method Index.append of Index(['Year', '...
# ..         ...         ...                                                ...
# 589      Cairo      4961.0  <bound method Index.append of Index(['Year', '...
# 590      Cairo     27500.0  <bound method Index.append of Index(['Year', '...
# 591      Cairo     16090.0  <bound method Index.append of Index(['Year', '...
# 592      Cairo     12098.0  <bound method Index.append of Index(['Year', '...
# 593      Cairo      7530.0  <bound method Index.append of Index(['Year', '...
#
# [594 rows x 13 columns]

# %% [markdown]
# 18.	Write a Pandas program to iterate over rows in your DataFrame.

# %%
for index, row in df.iterrows():
    print(index, row)
# Out:
# 0 Year                                                               1957.0
# Date                                                            10-Feb-57
# Time                                                                  NaN
# HomeTeam                                                           Sudan
# AwayTeam                                                            Egypt
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         2.0
# Stage                                                          Semifinals
# SpecialWinConditions                                                  NaN
# Stadium                                                 Municipal Stadium
# City                                                             Khartoum
# Attendance                                                        30000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 0, dtype: object
# 1 Year                                                               1957.0
# Date                                                            10-Feb-57
# Time                                                                  NaN
# HomeTeam                                                        Ethiopia
# AwayTeam                                                     South Africa
# HomeTeamGoals                                                         NaN
# AwayTeamGoals                                                         NaN
# Stage                                                          Semifinals
# SpecialWinConditions    Ethiopia  wins due to disqualification of othe...
# Stadium                                                               NaN
# City                                                                  NaN
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 1, dtype: object
# 2 Year                                                               1957.0
# Date                                                            16-Feb-57
# Time                                                                  NaN
# HomeTeam                                                           Egypt
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                        10.0
# Stage                                                               Final
# SpecialWinConditions                                                  NaN
# Stadium                                                 Municipal Stadium
# City                                                             Khartoum
# Attendance                                                        30000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 2, dtype: object
# 3 Year                                                               1959.0
# Date                                                            22-May-59
# Time                                                                  NaN
# HomeTeam                                                            Egypt
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                         0.0
# Stage                                                    Final Tournament
# SpecialWinConditions                                                  NaN
# Stadium                                             Prince Farouk Stadium
# City                                                                Cairo
# Attendance                                                        30000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 3, dtype: object
# 4 Year                                                               1959.0
# Date                                                            25-May-59
# Time                                                                  NaN
# HomeTeam                                                           Sudan
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         0.0
# Stage                                                    Final Tournament
# SpecialWinConditions                                                  NaN
# Stadium                                             Prince Farouk Stadium
# City                                                                Cairo
# Attendance                                                        20000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 4, dtype: object
# 5 Year                                                               1959.0
# Date                                                            29-May-59
# Time                                                                  NaN
# HomeTeam                                                            Egypt
# AwayTeam                                                            Sudan
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         1.0
# Stage                                                    Final Tournament
# SpecialWinConditions                                                  NaN
# Stadium                                             Prince Farouk Stadium
# City                                                                Cairo
# Attendance                                                        30000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 5, dtype: object
# 6 Year                                                               1962.0
# Date                                                            14-Jan-62
# Time                                                                  NaN
# HomeTeam                                                        Ethiopia
# AwayTeam                                                          Tunisia
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                         2.0
# Stage                                                          Semifinals
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        30000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 6, dtype: object
# 7 Year                                                               1962.0
# Date                                                            18-Jan-62
# Time                                                                  NaN
# HomeTeam                                                            Egypt
# AwayTeam                                                           Uganda
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         1.0
# Stage                                                          Semifinals
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        30000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 7, dtype: object
# 8 Year                                                               1962.0
# Date                                                            20-Jan-62
# Time                                                                  NaN
# HomeTeam                                                         Tunisia
# AwayTeam                                                           Uganda
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         0.0
# Stage                                                   Third place match
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 8, dtype: object
# 9 Year                                                               1962.0
# Date                                                            21-Jan-62
# Time                                                                  NaN
# HomeTeam                                                        Ethiopia
# AwayTeam                                                            Egypt
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                         2.0
# Stage                                                               Final
# SpecialWinConditions                                win after extra time
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 9, dtype: object
# 10 Year                                                               1963.0
# Date                                                            24-Nov-63
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                                          Tunisia
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                              Accra Sports Stadium
# City                                                                Accra
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 10, dtype: object
# 11 Year                                                               1963.0
# Date                                                            26-Nov-63
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                              Accra Sports Stadium
# City                                                                Accra
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 11, dtype: object
# 12 Year                                                               1963.0
# Date                                                            28-Nov-63
# Time                                                                  NaN
# HomeTeam                                                        Ethiopia
# AwayTeam                                                          Tunisia
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                         2.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                              Accra Sports Stadium
# City                                                                Accra
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 12, dtype: object
# 13 Year                                                               1963.0
# Date                                                            24-Nov-63
# Time                                                                  NaN
# HomeTeam                                                            Egypt
# AwayTeam                                                          Nigeria
# HomeTeamGoals                                                         6.0
# AwayTeamGoals                                                         3.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                             Kumasi Sports Stadium
# City                                                               Kumasi
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 13, dtype: object
# 14 Year                                                               1963.0
# Date                                                            26-Nov-63
# Time                                                                  NaN
# HomeTeam                                                            Egypt
# AwayTeam                                                            Sudan
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         2.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                             Kumasi Sports Stadium
# City                                                               Kumasi
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 14, dtype: object
# 15 Year                                                               1963.0
# Date                                                            28-Nov-63
# Time                                                                  NaN
# HomeTeam                                                           Sudan
# AwayTeam                                                          Nigeria
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                             Kumasi Sports Stadium
# City                                                               Kumasi
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 15, dtype: object
# 16 Year                                                               1963.0
# Date                                                            30-Nov-63
# Time                                                                  NaN
# HomeTeam                                                            Egypt
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         0.0
# Stage                                                   Third place match
# SpecialWinConditions                                                  NaN
# Stadium                                              Accra Sports Stadium
# City                                                                Accra
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 16, dtype: object
# 17 Year                                                               1963.0
# Date                                                             1-Dec-63
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                                            Sudan
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         0.0
# Stage                                                               Final
# SpecialWinConditions                                                  NaN
# Stadium                                              Accra Sports Stadium
# City                                                                Accra
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 17, dtype: object
# 18 Year                                                               1965.0
# Date                                                            12-Nov-65
# Time                                                                  NaN
# HomeTeam                                                         Tunisia
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                              Stade Chedli Zouiten
# City                                                                Tunis
# Attendance                                                        16000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 18, dtype: object
# 19 Year                                                               1965.0
# Date                                                            14-Nov-65
# Time                                                                  NaN
# HomeTeam                                                         Senegal
# AwayTeam                                                          Tunisia
# HomeTeamGoals                                                         0.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                              Stade Chedli Zouiten
# City                                                                Tunis
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 19, dtype: object
# 20 Year                                                               1965.0
# Date                                                            19-Nov-65
# Time                                                                  NaN
# HomeTeam                                                         Senegal
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         5.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                              Stade Chedli Zouiten
# City                                                                Tunis
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 20, dtype: object
# 21 Year                                                               1965.0
# Date                                                            12-Nov-65
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                              Congo-Léopoldville
# HomeTeamGoals                                                         5.0
# AwayTeamGoals                                                         2.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                             Stade Bou Ali Lahouar
# City                                                               Sousse
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 21, dtype: object
# 22 Year                                                               1965.0
# Date                                                            14-Nov-65
# Time                                                                  NaN
# HomeTeam                                                     Ivory Coast
# AwayTeam                                              Congo-Léopoldville
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                                 Stade Taïeb Mhiri
# City                                                                 Sfax
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 22, dtype: object
# 23 Year                                                               1965.0
# Date                                                            19-Nov-65
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                                      Ivory Coast
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                                 Stade Ahmed Bsiri
# City                                                              Bizerte
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 23, dtype: object
# 24 Year                                                               1965.0
# Date                                                            21-Nov-65
# Time                                                                  NaN
# HomeTeam                                                         Senegal
# AwayTeam                                                      Ivory Coast
# HomeTeamGoals                                                         0.0
# AwayTeamGoals                                                         1.0
# Stage                                                   Third place match
# SpecialWinConditions                                                  NaN
# Stadium                                              Stade Chedli Zouiten
# City                                                                Tunis
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 24, dtype: object
# 25 Year                                                               1965.0
# Date                                                            21-Nov-65
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                                          Tunisia
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         2.0
# Stage                                                               Final
# SpecialWinConditions                                win after extra time
# Stadium                                              Stade Chedli Zouiten
# City                                                                Tunis
# Attendance                                                            NaN
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 25, dtype: object
# 26 Year                                                               1968.0
# Date                                                            12-Jan-68
# Time                                                                  NaN
# HomeTeam                                                        Ethiopia
# AwayTeam                                                           Uganda
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        20000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 26, dtype: object
# 27 Year                                                               1968.0
# Date                                                            12-Jan-68
# Time                                                                  NaN
# HomeTeam                                                     Ivory Coast
# AwayTeam                                                          Algeria
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        20000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 27, dtype: object
# 28 Year                                                               1968.0
# Date                                                            14-Jan-68
# Time                                                                  NaN
# HomeTeam                                                        Ethiopia
# AwayTeam                                                      Ivory Coast
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        25000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 28, dtype: object
# 29 Year                                                               1968.0
# Date                                                            14-Jan-68
# Time                                                                  NaN
# HomeTeam                                                         Algeria
# AwayTeam                                                           Uganda
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        25000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 29, dtype: object
# 30 Year                                                               1968.0
# Date                                                            16-Jan-68
# Time                                                                  NaN
# HomeTeam                                                     Ivory Coast
# AwayTeam                                                           Uganda
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        15000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 30, dtype: object
# 31 Year                                                               1968.0
# Date                                                            16-Jan-68
# Time                                                                  NaN
# HomeTeam                                                        Ethiopia
# AwayTeam                                                          Algeria
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        20000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 31, dtype: object
# 32 Year                                                               1968.0
# Date                                                            12-Jan-68
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                                          Senegal
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         2.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                                    Cicero Stadium
# City                                                               Asmara
# Attendance                                                         3000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 32, dtype: object
# 33 Year                                                               1968.0
# Date                                                            12-Jan-68
# Time                                                                  NaN
# HomeTeam                                                  Congo-Kinshasa
# AwayTeam                                                Congo-Brazzaville
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                                    Cicero Stadium
# City                                                               Asmara
# Attendance                                                         4000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 33, dtype: object
# 34 Year                                                               1968.0
# Date                                                            14-Jan-68
# Time                                                                  NaN
# HomeTeam                                                         Senegal
# AwayTeam                                                Congo-Brazzaville
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                                    Cicero Stadium
# City                                                               Asmara
# Attendance                                                         3000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 34, dtype: object
# 35 Year                                                               1968.0
# Date                                                            14-Jan-68
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                                   Congo-Kinshasa
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                                    Cicero Stadium
# City                                                               Asmara
# Attendance                                                         3000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 35, dtype: object
# 36 Year                                                               1968.0
# Date                                                            16-Jan-68
# Time                                                                  NaN
# HomeTeam                                                  Congo-Kinshasa
# AwayTeam                                                          Senegal
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                                    Cicero Stadium
# City                                                               Asmara
# Attendance                                                         3000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 36, dtype: object
# 37 Year                                                               1968.0
# Date                                                            16-Jan-68
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                                Congo-Brazzaville
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group B
# SpecialWinConditions                                                  NaN
# Stadium                                                    Cicero Stadium
# City                                                               Asmara
# Attendance                                                         3000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 37, dtype: object
# 38 Year                                                               1968.0
# Date                                                            19-Jan-68
# Time                                                                  NaN
# HomeTeam                                                        Ethiopia
# AwayTeam                                                   Congo-Kinshasa
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         3.0
# Stage                                                         Semi-finals
# SpecialWinConditions                                win after extra time
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        25000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 38, dtype: object
# 39 Year                                                               1968.0
# Date                                                            19-Jan-68
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                                      Ivory Coast
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                         3.0
# Stage                                                         Semi-finals
# SpecialWinConditions                                win after extra time
# Stadium                                                    Cicero Stadium
# City                                                               Asmara
# Attendance                                                         5000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 39, dtype: object
# 40 Year                                                               1968.0
# Date                                                            21-Jan-68
# Time                                                                  NaN
# HomeTeam                                                     Ivory Coast
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         0.0
# Stage                                                   Third place match
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        10000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 40, dtype: object
# 41 Year                                                               1968.0
# Date                                                            21-Jan-68
# Time                                                                  NaN
# HomeTeam                                                  Congo-Kinshasa
# AwayTeam                                                            Ghana
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         0.0
# Stage                                                               Final
# SpecialWinConditions                                                  NaN
# Stadium                                            Hailé Sélassié Stadium
# City                                                          Addis Ababa
# Attendance                                                        25000.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 41, dtype: object
# 42 Year                                                               1970.0
# Date                                                             6-Feb-70
# Time                                                                  NaN
# HomeTeam                                                        Cameroon
# AwayTeam                                                      Ivory Coast
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         2.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                                 Municipal Stadium
# City                                                             Khartoum
# Attendance                                                        14464.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 42, dtype: object
# 43 Year                                                               1970.0
# Date                                                             6-Feb-70
# Time                                                                  NaN
# HomeTeam                                                           Sudan
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                                 Municipal Stadium
# City                                                             Khartoum
# Attendance                                                        14464.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 43, dtype: object
# 44 Year                                                               1970.0
# Date                                                             8-Feb-70
# Time                                                                  NaN
# HomeTeam                                                        Cameroon
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         3.0
# AwayTeamGoals                                                         2.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                                 Municipal Stadium
# City                                                             Khartoum
# Attendance                                                         9864.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 44, dtype: object
# 45 Year                                                               1970.0
# Date                                                             8-Feb-70
# Time                                                                  NaN
# HomeTeam                                                     Ivory Coast
# AwayTeam                                                            Sudan
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                                 Municipal Stadium
# City                                                             Khartoum
# Attendance                                                         9864.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 45, dtype: object
# 46 Year                                                               1970.0
# Date                                                            10-Feb-70
# Time                                                                  NaN
# HomeTeam                                                     Ivory Coast
# AwayTeam                                                         Ethiopia
# HomeTeamGoals                                                         6.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                                 Municipal Stadium
# City                                                             Khartoum
# Attendance                                                         9770.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 46, dtype: object
# 47 Year                                                               1970.0
# Date                                                            10-Feb-70
# Time                                                                  NaN
# HomeTeam                                                           Sudan
# AwayTeam                                                         Cameroon
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group A
# SpecialWinConditions                                                  NaN
# Stadium                                                 Municipal Stadium
# City                                                             Khartoum
# Attendance                                                         9770.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 47, dtype: object
# 48 Year                                                               1970.0
# Date                                                             7-Feb-70
# Time                                                                  NaN
# HomeTeam                                                           Ghana
# AwayTeam                                                   Congo-Kinshasa
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         0.0
# ...
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 587, dtype: object
# 588 Year                                                               2019.0
# Date                                            23 June 2019 (2019-06-23)
# Time                                                                16:30
# HomeTeam                                                         Morocco
# AwayTeam                                                          Namibia
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group D
# SpecialWinConditions                                                  NaN
# Stadium                                                  Al Salam Stadium
# City                                                                Cairo
# Attendance                                                         6857.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 588, dtype: object
# 589 Year                                                               2019.0
# Date                                            24 June 2019 (2019-06-24)
# Time                                                                16:30
# HomeTeam                                                     Ivory Coast
# AwayTeam                                                     South Africa
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group D
# SpecialWinConditions                                                  NaN
# Stadium                                                  Al Salam Stadium
# City                                                                Cairo
# Attendance                                                         4961.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 589, dtype: object
# 590 Year                                                               2019.0
# Date                                            28 June 2019 (2019-06-28)
# Time                                                                19:00
# HomeTeam                                                         Morocco
# AwayTeam                                                      Ivory Coast
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group D
# SpecialWinConditions                                                  NaN
# Stadium                                                  Al Salam Stadium
# City                                                                Cairo
# Attendance                                                        27500.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 590, dtype: object
# 591 Year                                                               2019.0
# Date                                            28 June 2019 (2019-06-28)
# Time                                                                22:00
# HomeTeam                                                    South Africa
# AwayTeam                                                          Namibia
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group D
# SpecialWinConditions                                                  NaN
# Stadium                                                  Al Salam Stadium
# City                                                                Cairo
# Attendance                                                        16090.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 591, dtype: object
# 592 Year                                                               2019.0
# Date                                             1 July 2019 (2019-07-01)
# Time                                                                18:00
# HomeTeam                                                    South Africa
# AwayTeam                                                          Morocco
# HomeTeamGoals                                                         0.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group D
# SpecialWinConditions                                                  NaN
# Stadium                                                  Al Salam Stadium
# City                                                                Cairo
# Attendance                                                        12098.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 592, dtype: object
# 593 Year                                                               2019.0
# Date                                             1 July 2019 (2019-07-01)
# Time                                                                18:00
# HomeTeam                                                         Namibia
# AwayTeam                                                      Ivory Coast
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         4.0
# Stage                                                             Group D
# SpecialWinConditions                                                  NaN
# Stadium                                                   30 June Stadium
# City                                                                Cairo
# Attendance                                                         7530.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 593, dtype: object
# 594 Year                                                               2019.0
# Date                                            24 June 2019 (2019-06-24)
# Time                                                                19:00
# HomeTeam                                                         Tunisia
# AwayTeam                                                           Angola
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group E
# SpecialWinConditions                                                  NaN
# Stadium                                                      Suez Stadium
# City                                                                 Suez
# Attendance                                                         7345.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 594, dtype: object
# 595 Year                                                               2019.0
# Date                                            24 June 2019 (2019-06-24)
# Time                                                                22:00
# HomeTeam                                                            Mali
# AwayTeam                                                       Mauritania
# HomeTeamGoals                                                         4.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group E
# SpecialWinConditions                                                  NaN
# Stadium                                                      Suez Stadium
# City                                                                 Suez
# Attendance                                                         6202.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 595, dtype: object
# 596 Year                                                               2019.0
# Date                                            28 June 2019 (2019-06-28)
# Time                                                                16:30
# HomeTeam                                                         Tunisia
# AwayTeam                                                             Mali
# HomeTeamGoals                                                         1.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group E
# SpecialWinConditions                                                  NaN
# Stadium                                                      Suez Stadium
# City                                                                 Suez
# Attendance                                                        16085.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 596, dtype: object
# 597 Year                                                               2019.0
# Date                                            29 June 2019 (2019-06-29)
# Time                                                                16:30
# HomeTeam                                                      Mauritania
# AwayTeam                                                           Angola
# HomeTeamGoals                                                         0.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group E
# SpecialWinConditions                                                  NaN
# Stadium                                                      Suez Stadium
# City                                                                 Suez
# Attendance                                                        10120.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 597, dtype: object
# 598 Year                                                               2019.0
# Date                                             2 July 2019 (2019-07-02)
# Time                                                                21:00
# HomeTeam                                                      Mauritania
# AwayTeam                                                          Tunisia
# HomeTeamGoals                                                         0.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group E
# SpecialWinConditions                                                  NaN
# Stadium                                                      Suez Stadium
# City                                                                 Suez
# Attendance                                                         7732.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 598, dtype: object
# 599 Year                                                               2019.0
# Date                                             2 July 2019 (2019-07-02)
# Time                                                                21:00
# HomeTeam                                                          Angola
# AwayTeam                                                             Mali
# HomeTeamGoals                                                         0.0
# AwayTeamGoals                                                         1.0
# Stage                                                             Group E
# SpecialWinConditions                                                  NaN
# Stadium                                                  Ismailia Stadium
# City                                                             Ismailia
# Attendance                                                         8135.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 599, dtype: object
# 600 Year                                                               2019.0
# Date                                            25 June 2019 (2019-06-25)
# Time                                                                19:00
# HomeTeam                                                        Cameroon
# AwayTeam                                                    Guinea-Bissau
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group F
# SpecialWinConditions                                                  NaN
# Stadium                                                  Ismailia Stadium
# City                                                             Ismailia
# Attendance                                                         5983.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 600, dtype: object
# 601 Year                                                               2019.0
# Date                                            25 June 2019 (2019-06-25)
# Time                                                                22:00
# HomeTeam                                                           Ghana
# AwayTeam                                                            Benin
# HomeTeamGoals                                                         2.0
# AwayTeamGoals                                                         2.0
# Stage                                                             Group F
# SpecialWinConditions                                                  NaN
# Stadium                                                  Ismailia Stadium
# City                                                             Ismailia
# Attendance                                                         8094.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 601, dtype: object
# 602 Year                                                               2019.0
# Date                                            29 June 2019 (2019-06-29)
# Time                                                                19:00
# HomeTeam                                                        Cameroon
# AwayTeam                                                            Ghana
# HomeTeamGoals                                                         0.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group F
# SpecialWinConditions                                                  NaN
# Stadium                                                  Ismailia Stadium
# City                                                             Ismailia
# Attendance                                                        16724.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 602, dtype: object
# 603 Year                                                               2019.0
# Date                                            29 June 2019 (2019-06-29)
# Time                                                                22:00
# HomeTeam                                                           Benin
# AwayTeam                                                    Guinea-Bissau
# HomeTeamGoals                                                         0.0
# AwayTeamGoals                                                         0.0
# Stage                                                             Group F
# SpecialWinConditions                                                  NaN
# Stadium                                                  Ismailia Stadium
# City                                                             Ismailia
# Attendance                                                         9212.0
# Form                    <bound method Index.append of Index(['Year', '...
# Name: 603, dtype: object

# %% [markdown]
# 20.	Write a Pandas program to delete DataFrame row(s) whose value is 0 in the ‘HomeTeamGoals’ columns.

# %%
df10 = df[df['HomeTeamGoals']!=0]
print(df10)
# Out:
#        Year                      Date   Time    HomeTeam        AwayTeam  \
# 0    1957.0                  10-Feb-57    NaN     Sudan            Egypt
# 1    1957.0                  10-Feb-57    NaN  Ethiopia     South Africa
# 2    1957.0                  16-Feb-57    NaN     Egypt         Ethiopia
# 3    1959.0                  22-May-59    NaN      Egypt        Ethiopia
# 4    1959.0                  25-May-59    NaN     Sudan         Ethiopia
# ..      ...                        ...    ...        ...             ...
# 594  2019.0  24 June 2019 (2019-06-24)  19:00   Tunisia           Angola
# 595  2019.0  24 June 2019 (2019-06-24)  22:00      Mali       Mauritania
# 596  2019.0  28 June 2019 (2019-06-28)  16:30   Tunisia             Mali
# 600  2019.0  25 June 2019 (2019-06-25)  19:00  Cameroon    Guinea-Bissau
# 601  2019.0  25 June 2019 (2019-06-25)  22:00     Ghana            Benin
#
#      HomeTeamGoals  AwayTeamGoals             Stage  \
# 0              1.0            2.0        Semifinals
# 1              NaN            NaN        Semifinals
# 2              4.0           10.0             Final
# 3              4.0            0.0  Final Tournament
# 4              1.0            0.0  Final Tournament
# ..             ...            ...               ...
# 594            1.0            1.0           Group E
# 595            4.0            1.0           Group E
# 596            1.0            1.0           Group E
# 600            2.0            0.0           Group F
# 601            2.0            2.0           Group F
#
#                                   SpecialWinConditions                Stadium  \
# 0                                                  NaN      Municipal Stadium
# 1    Ethiopia  wins due to disqualification of othe...                    NaN
# 2                                                  NaN      Municipal Stadium
# 3                                                  NaN  Prince Farouk Stadium
# 4                                                  NaN  Prince Farouk Stadium
# ..                                                 ...                    ...
# 594                                                NaN           Suez Stadium
# 595                                                NaN           Suez Stadium
# 596                                                NaN           Suez Stadium
# 600                                                NaN       Ismailia Stadium
# 601                                                NaN       Ismailia Stadium
#
#           City  Attendance                                               Form
# 0     Khartoum     30000.0  <bound method Index.append of Index(['Year', '...
# 1          NaN         NaN  <bound method Index.append of Index(['Year', '...
# 2     Khartoum     30000.0  <bound method Index.append of Index(['Year', '...
# 3        Cairo     30000.0  <bound method Index.append of Index(['Year', '...
# 4        Cairo     20000.0  <bound method Index.append of Index(['Year', '...
# ..         ...         ...                                                ...
# 594       Suez      7345.0  <bound method Index.append of Index(['Year', '...
# 595       Suez      6202.0  <bound method Index.append of Index(['Year', '...
# 596       Suez     16085.0  <bound method Index.append of Index(['Year', '...
# 600   Ismailia      5983.0  <bound method Index.append of Index(['Year', '...
# 601   Ismailia      8094.0  <bound method Index.append of Index(['Year', '...
#
# [484 rows x 13 columns]
